# %%
from ultralytics import YOLO

# %% [markdown]
# ## Initialising

# %%
model = YOLO("yolo11m.yaml").load("yolo11m.pt")

# %% [markdown]
# ## Training

# %%
results = model.train(
    data="config.yaml",
    cfg="hyp.yaml",
)

# %% [markdown]
# ## Evaluation

# %%
model = YOLO('runs/detect/train/weights/best.pt')
metrics = model.val(data='config.yaml', plots=True)
